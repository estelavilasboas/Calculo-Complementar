# %% [markdown]
# # Exercícios
#
# Siga as instruções para recriar os gráficos usando estes dados:
#
# ## Dados

# %%
import numpy as np
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# **Importe matplotlib.pyplot como plt e defina% matplotlib inline se você estiver usando o bloco de anotações jupyter. Que comando você usa se não estiver usando o notebook jupyter**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Exercício 1
#
# **Siga estas etapas:**
# * **Crie um objeto de figura chamado fig usando plt.figure ()**
# * **Use add_axes para adicionar um eixo à tela da figura em [0,0,1,1]. Chame esse novo eixo de eixo.**
# * **Plote (x, y) nesses eixos e defina os rótulos e títulos para coincidir com o gráfico abaixo:**

# %%
figure = plt.figure()
axes = figure.add_axes([0, 0, 1, 1])
axes.set_ylabel('y')
axes.set_xlabel('x')
axes.set_title('title')
axes.plot(x, y)

# %% [markdown]
# ## Exercício 2
# **Crie um objeto de figura e coloque dois eixos nele, ax1 e ax2. Localizado em [0,0,1,1] e [0,2,0,5, .2, .2], respectivamente.**

# %%
figure = plt.figure()
#0.2 0.4 0.6 0.8
axes1 = figure.add_axes([0, 0, 1, 1])
axes2 = figure.add_axes([.2, .5, .2, .2])

# %% [markdown]
# **Agora plote (x, y) nos dois eixos. E chame seu objeto de figura para mostrá-lo.**

# %%
figure = plt.figure()
axes1 = figure.add_axes([0, 0, 1, 1])
axes2 = figure.add_axes([.2, .5, .2, 0.2])
axes1.plot(x, y)
axes2.plot(x, y)

# %% [markdown]
# ## Exercício 3
#
# **Crie o gráfico abaixo adicionando dois eixos a um objeto de figura em [0,0,1,1] e [0,2,0,5, .4, .4]**

# %%
figure = plt.figure()
axes1 = figure.add_axes([0, 0, 1, 1])
axes2 = figure.add_axes([.2, .5, .4, .4])

# %% [markdown]
# **Agora use as matrizes x, ye z para recriar o gráfico abaixo. Observe os limites xlimits e y no gráfico inserido:**

# %%
figure = plt.figure()

axes = figure.add_axes([0, 0, 1, 1])
axes.set_xlabel('X')
axes.set_ylabel('Z')
axes.set_xlim((0, 100))

axes1 = figure.add_axes([.2, .5, .4, .4])
axes1.set_xlabel('X')
axes1.set_ylabel('Z')
axes1.set_xlim((20, 22))
axes1.set_ylim((30, 50))
axes1.set_title('zoom')

axes.plot(x, z)
axes1.plot(x, y)

# %% [markdown]
# ## Exercício 4
#
# **Use plt.subplots (nrows = 1, ncols = 2) para criar o gráfico abaixo.**

# %%
plt.subplots(1, 2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe4df6e2588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe4df65f6d8>],
#        dtype=object))

# %% [markdown]
# **Agora plote (x, y) e (x, z) nos eixos. Brinque com a largura de linha e o estilo**

# %%
figure, axes = plt.subplots(1, 2)
axes[0].plot(x, y, linestyle='dashed')
axes[1].plot(x, z, linewidth=5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-8b8d55472791> in <module>()
#       1 figure, axes = plt.subplots(1, 2)
# ----> 2 axes[0].plot(x, y, linestyle='dashed')
#       3 axes[1].plot(x, z, linewidth=5)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (100,)

# %% [markdown]
# **Veja se você pode redimensionar o gráfico adicionando o argumento figsize () em plt.subplots () está copiando e colando o código anterior.**

# %%
figure, axes = plt.subplots(1, 2, figsize=(10, 2))
axes[0].plot(x, y, linewidth=5)
axes[1].plot(x, z, linestyle='dashed')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-a99207d5b44d> in <module>()
#       1 figure, axes = plt.subplots(1, 2, figsize=(10, 2))
# ----> 2 axes[0].plot(x, y, linewidth=5)
#       3 axes[1].plot(x, z, linestyle='dashed')
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# --> 225             yield from self._plot_args(this, kwargs)
#     226
#     227     def get_next_color(self):
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     389             x, y = index_of(tup[-1])
#     390
# --> 391         x, y = self._xy_from_xy(x, y)
#     392
#     393         if self.command == 'plot':
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     268         if x.shape[0] != y.shape[0]:
#     269             raise ValueError("x and y must have same first dimension, but "
# --> 270                              "have shapes {} and {}".format(x.shape, y.shape))
#     271         if x.ndim > 2 or y.ndim > 2:
#     272             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (2,) and (100,)
